# %%
import pandas as pd
pd.set_option('max_rows',40)
pd.set_option('max_colwidth',400)
pd.describe_option('max_colwidth')
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
sns.color_palette("Paired")
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# display.max_colwidth : int or None
#     The maximum width in characters of a column in the repr of
#     a pandas data structure. When the column overflows, a "..."
#     placeholder is embedded in the output. A 'None' value means unlimited.
#     [default: 50] [currently: 400]

# %% [markdown]
# ### LOAD THE DATA SET

# %%
df = pd.read_csv('HR_Employee_Attrition_Data.csv');

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               3
# 3                 3          4  Life Sciences              1               4
# 4                 2          1        Medical              1               5
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ### EDA

# %%
## get shape and info of data 
print(df.shape)
df.info()
# Out:
# (2940, 35)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2940 entries, 0 to 2939
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       2940 non-null   int64
#  1   Attrition                 2940 non-null   object
#  2   BusinessTravel            2940 non-null   object
#  3   DailyRate                 2940 non-null   int64
#  4   Department                2940 non-null   object
#  5   DistanceFromHome          2940 non-null   int64
#  6   Education                 2940 non-null   int64
#  7   EducationField            2940 non-null   object
#  8   EmployeeCount             2940 non-null   int64
#  9   EmployeeNumber            2940 non-null   int64
#  10  EnvironmentSatisfaction   2940 non-null   int64
#  11  Gender                    2940 non-null   object
#  12  HourlyRate                2940 non-null   int64
# ...

# %% [markdown]
# ##### CHECK ALL THE COLUMNS

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ### Check if null value is present

# %%
# check null values 

df.value_counts
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ### Get Five no Summary

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  2940.000000  2940.000000       2940.000000  2940.000000         2940.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.133819   403.440447          8.105485     1.023991            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     2940.000000              2940.000000  2940.000000     2940.000000
# mean      1470.500000                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ### After seeing descibre matrix observed that StandardHours and Emplyee_Count column make no sense so we can drop

# %%
df.drop(columns= ['EmployeeCount','StandardHours'],inplace=True)

# %% [markdown]
# ### FIND CORELATED MATRIX

# %%
### FIND CORELATED MATRIX
corr_data = df.corr()
corr_data
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeNumber           -0.005175  -0.025742          0.016464   0.020950
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# ...

# %% [markdown]
# ### Draw heatmap to check correlation

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,10))
sns.heatmap(corr_data,linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Lets Start from target column Attration

# %%
### attration count in % 
fig_dms = (10,4)
fig, ax = plt.subplots(figsize=fig_dms)
attration = df.Attrition.value_counts()
show_in_percentage = (attration/2940 )*100
print('Attration Rate::' ,(attration/2940 )*100)
sns.barplot(y=show_in_percentage.index, x = show_in_percentage)
plt.show()
# Out:
# Attration Rate:: No     83.877551
# Yes    16.122449
# Name: Attrition, dtype: float64

# %% [markdown]
# ### Age group in company

# %%
sns.distplot(df['Age'])

# Age group in datasets states that employee age concentrated id=s b/w (25-45) year
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### Environment Stratification LEVAL

# %%
# Job Environment Stratification of employee (rating scale data 1,
# 2, 3, 4 categorical variable nominal/ordinal data)
satisfaction = ['low','med','high'];
fig_dms = (20,6)
fig, ax = plt.subplots(figsize=fig_dms)
sns.countplot(x='EnvironmentSatisfaction', ax=ax, data=df)
plt.show()

# %% [markdown]
# ### box plots b/w age and attriation

# %%
# As below box plot results outcome is attrition is more common in the younger age groups
# and it is more likely with females.
fig_dms = (15,6)
fig, ax = plt.subplots(figsize=fig_dms)
sns.boxplot(y=df['Age'],x=df['Attrition'], hue=df['Gender'])
plt.show()

# %%
# plot b/w ahe vs attration with marital status
fig_dms = (15,6)
fig, ax = plt.subplots(figsize=fig_dms)
# Save a palette to a variable:
sns.boxplot(y=df['Age'],x=df['Attrition'], hue=df['MaritalStatus'])
plt.show()

# %%
fig_dms = (15,6)
fig, ax = plt.subplots(figsize=fig_dms)
sns.boxplot(y=df['Age'],x=df['Attrition'], hue=df['JobSatisfaction'])
plt.show()

# %% [markdown]
# ### Check status of business traveller filed

# %%
## We can obsetve that count of Rearly traveller emp and non traveller emp is more than 22500.
fig_dms = (10,4)
fig, ax = plt.subplots(figsize=fig_dms)
business_Traveller = df.BusinessTravel.value_counts()
sns.barplot(y=business_Traveller.index, x = business_Traveller)
plt.show()

# %%
## We can say that Non treveller and travel Rarely emplyee leaving complany frequantly.
fig_dms = (15,6)
fig, ax = plt.subplots(figsize=fig_dms)
sns.boxplot(df['Attrition'],df['Age'],hue=df['BusinessTravel'])
plt.show()

# %%
fig_dms = (10,4)
fig, ax = plt.subplots(figsize=fig_dms)
department = df.Department.value_counts()
sns.barplot(y=department.index, x = department)
plt.show()

# %%
## We can attration is more in sales and Research and developemnt department
fig_dms = (15,6)
fig, ax = plt.subplots(figsize=fig_dms)
sns.boxplot(df['Attrition'],df['Age'],hue=df['Department'])
plt.show()

# %%
## By seeing below plots we can say that people having high education tend to leave the company less
fig_dms = (15,6)
fig, ax = plt.subplots(figsize=fig_dms)
sns.boxplot(df['Attrition'],df['MonthlyIncome'],hue=df['Education'])
plt.show()

# %%
fig_dms = (15,6)
fig, ax = plt.subplots(figsize=fig_dms)
sns.boxplot(df['Attrition'],df['MonthlyIncome'],hue=df['JobInvolvement'])
plt.show()

# %%
sfig_dms = (15,6)
fig, ax = plt.subplots(figsize=fig_dms)
sns.boxplot(df['Attrition'],df['MonthlyIncome'],hue=df['OverTime'])
plt.show()

# %%
## By seeing below plots we can say that people having high education tend to leave the company less
fig_dms = (15,6)
fig, ax = plt.subplots(figsize=fig_dms)
sns.boxplot(df['Attrition'],df['MonthlyIncome'],hue=df['StockOptionLevel'])
plt.show()

# %%
## By seeing below plots we can say below 10 years serving in company leaving frequently.
fig_dms = (15,6)
fig, ax = plt.subplots(figsize=fig_dms)
sns.boxplot(df['Attrition'],df['YearsAtCompany'],hue=df['Gender'])
plt.show()

# %%
fig_dms = (15,4)
fig, ax = plt.subplots(figsize=fig_dms)
sns.boxplot(df['MonthlyIncome'])
plt.show()

# %%
fig_dms = (15,4)
fig, ax = plt.subplots(figsize=fig_dms)
sns.distplot(df['MonthlyIncome'])
plt.show()

# %%
fig_dms = (15,4)
fig, ax = plt.subplots(figsize=fig_dms)
sns.boxplot(df['MonthlyRate'])
plt.show()

# %%
fig_dms = (15,4)
fig, ax = plt.subplots(figsize=fig_dms)
sns.distplot(df['MonthlyRate'])
plt.show()

# %%
fig_dms = (15,4)
fig, ax = plt.subplots(figsize=fig_dms)
sns.boxplot(df['HourlyRate'])
plt.show()

# %%
fig_dms = (15,4)
fig, ax = plt.subplots(figsize=fig_dms)
sns.distplot(df['HourlyRate'])
plt.show()

# %%
col = ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
       'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
       'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
       'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
       'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
       'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']

# %%
## By seeing below plots we can say below 10 years serving in company leaving frequently.
sns.pairplot(df[col])
plt.show()

# %% [markdown]
# ## corr matrix with specific column

# %%
data_n=df[['Age','DailyRate','HourlyRate','MonthlyIncome','MonthlyRate','PercentSalaryHike','TotalWorkingYears','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager','NumCompaniesWorked']]

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(data_n.corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>
